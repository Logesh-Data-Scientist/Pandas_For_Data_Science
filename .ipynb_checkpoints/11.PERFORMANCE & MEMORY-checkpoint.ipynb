# %%
import pandas as pd
import numpy as np

data = {
    "A": [1, 2, 3, 4],
    "B": [10.5, 20.1, 30.2, 40.3],
    "C": ["x", "y", "z", "w"]
}

df = pd.DataFrame(data)
df
# Out:
#    A     B  C
# 0  1  10.5  x
# 1  2  20.1  y
# 2  3  30.2  z
# 3  4  40.3  w

# %% [markdown]
# ## df.copy()

# %%
df_copy = df.copy()
df_copy["A"] = df_copy["A"] * 10

df
df_copy
# Out:
#     A     B  C
# 0  10  10.5  x
# 1  20  20.1  y
# 2  30  30.2  z
# 3  40  40.3  w

# %% [markdown]
# ## pd.read_csv(chunksize)

# %%
for chunk in pd.read_csv(r"C:\Users\Hey!\OneDrive\Desktop\Pandas-for-Data-Science\dataset\countries of the world.csv", chunksize=2):
    print(chunk)
# Out:
#         Country                               Region
# 0  Afghanistan         ASIA (EX. NEAR EAST)
# 1      Albania   EASTERN EUROPE
#            Country                               Region
# 2         Algeria   NORTHERN AFRICA
# 3  American Samoa   OCEANIA
#     Country                               Region
# 4  Andorra   WESTERN EUROPE
# 5   Angola   SUB-SAHARAN AFRICA
#               Country                   Region
# 6           Anguilla   LATIN AMER. & CARIB
# 7  Antigua & Barbuda   LATIN AMER. & CARIB
#       Country                   Region
# 8  Argentina   LATIN AMER. & CARIB
# 9    Armenia      C.W. OF IND. STATES
#        Country                               Region
# 10      Aruba               LATIN AMER. & CARIB
# 11  Australia   OCEANIA
#         Country                               Region
# 12     Austria   WESTERN EUROPE
# 13  Azerbaijan                  C.W. OF IND. STATES
#           Country                               Region
# ...

# %% [markdown]
# ## df.select_dtypes()

# %%
# Select numeric columns
df.select_dtypes(include=["number"])

# Select object (string) columns
df.select_dtypes(include=["object"])
# Out:
# C:\Users\Hey!\AppData\Local\Temp\ipykernel_9744\2046934436.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include=["object"])
#    C
# 0  x
# 1  y
# 2  z
# 3  w

# %% [markdown]
# ## df.convert_dtypes()

# %%
df_converted = df.convert_dtypes()
df_converted.dtypes
# Out:
# A      Int64
# B    Float64
# C     string
# dtype: object
