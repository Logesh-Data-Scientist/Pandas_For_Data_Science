# %%
import pandas as pd
import numpy as np

data = {
    "A": [10, 20, 30, 40, 50],
    "B": [5, 15, 25, 35, 45],
    "C": [2, 4, 6, 8, 10]
}

df = pd.DataFrame(data)
df
# Out:
#     A   B   C
# 0  10   5   2
# 1  20  15   4
# 2  30  25   6
# 3  40  35   8
# 4  50  45  10

# %% [markdown]
# ## df.mean()

# %%
df.mean()
# Out:
# A    30.0
# B    25.0
# C     6.0
# dtype: float64

# %% [markdown]
# ## df.sum()

# %%
df.sum()
# Out:
# A    150
# B    125
# C     30
# dtype: int64

# %% [markdown]
# ## df.median()

# %%
df.median()
# Out:
# A    30.0
# B    25.0
# C     6.0
# dtype: float64

# %% [markdown]
# ## df.std() / df.var()

# %%
df.std()
df.var()
# Out:
# A    250.0
# B    250.0
# C     10.0
# dtype: float64

# %% [markdown]
# ## df.corr()

# %%
df.corr()
# Out:
#      A    B    C
# A  1.0  1.0  1.0
# B  1.0  1.0  1.0
# C  1.0  1.0  1.0

# %% [markdown]
# ## df.cumsum()

# %%
df.cumsum()
# Out:
#      A    B   C
# 0   10    5   2
# 1   30   20   6
# 2   60   45  12
# 3  100   80  20
# 4  150  125  30

# %% [markdown]
# ## df.pct_change()

# %%
df.pct_change()
# Out:
#           A         B         C
# 0       NaN       NaN       NaN
# 1  1.000000  2.000000  1.000000
# 2  0.500000  0.666667  0.500000
# 3  0.333333  0.400000  0.333333
# 4  0.250000  0.285714  0.250000

# %% [markdown]
# ## df.cov()

# %%
df.cov()
# Out:
#        A      B     C
# A  250.0  250.0  50.0
# B  250.0  250.0  50.0
# C   50.0   50.0  10.0

# %% [markdown]
# ## df.quantile()

# %%
df.quantile(0.5)  # median
# Out:
# A    30.0
# B    25.0
# C     6.0
# Name: 0.5, dtype: float64

# %% [markdown]
# ## df.abs()

# %%
df_negative = pd.DataFrame({"A": [-10, -20, 30]})

df_negative.abs()
# Out:
#     A
# 0  10
# 1  20
# 2  30

# %% [markdown]
# ## df.diff()

# %%
df.diff()
# Out:
#       A     B    C
# 0   NaN   NaN  NaN
# 1  10.0  10.0  2.0
# 2  10.0  10.0  2.0
# 3  10.0  10.0  2.0
# 4  10.0  10.0  2.0
