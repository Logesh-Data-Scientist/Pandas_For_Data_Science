# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\Hey!\OneDrive\Desktop\Pandas-for-Data-Science\dataset\countries of the world.csv")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df.head()   # first 5 rows
# Out:
#            Country                               Region
# 0     Afghanistan         ASIA (EX. NEAR EAST)
# 1         Albania   EASTERN EUROPE
# 2         Algeria   NORTHERN AFRICA
# 3  American Samoa   OCEANIA
# 4         Andorra   WESTERN EUROPE

# %%
df.head(10)   # first 10 rows
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df.tail()   # last 5 rows
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
df.tail(10)   # last 10 rows
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  227 non-null    str
#  1   Region   227 non-null    str
# dtypes: str(2)
# memory usage: 3.7 KB

# %%
df.describe()
# Out:
#              Country                               Region
# count            227                                  227
# unique           227                                   11
# top     Afghanistan   SUB-SAHARAN AFRICA
# freq               1                                   51

# %%
df.shape    # rows x columns
# Out:
# (227, 2)

# %%
df.dtypes
# Out:
# Country    str
# Region     str
# dtype: object

# %%
df["Region"].value_counts()
# Out:
# Region
# SUB-SAHARAN AFRICA                     51
# LATIN AMER. & CARIB                    45
# ASIA (EX. NEAR EAST)                   28
# WESTERN EUROPE                         28
# OCEANIA                                21
# NEAR EAST                              16
# EASTERN EUROPE                         12
# C.W. OF IND. STATES                    12
# NORTHERN AFRICA                         6
# NORTHERN AMERICA                        5
# BALTICS                                 3
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Country    0
# Region     0
# dtype: int64

# %%
df.nunique()
# Out:
# Country    227
# Region      11
# dtype: int64

# %%
df.sample(20)   # random samples
# Out:
#                                Country                               Region
# 175  Saint Vincent and the Grenadines               LATIN AMER. & CARIB
# 86                             Guinea   SUB-SAHARAN AFRICA
# 29                             Brunei         ASIA (EX. NEAR EAST)
# 95                          Indonesia         ASIA (EX. NEAR EAST)
# 19                            Belgium   WESTERN EUROPE
# 13                         Azerbaijan                  C.W. OF IND. STATES
# 129                             Malta   WESTERN EUROPE
# 188                           Somalia   SUB-SAHARAN AFRICA
# 197                             Syria   NEAR EAST
# 142                        Mozambique   SUB-SAHARAN AFRICA
# 90                           Honduras               LATIN AMER. & CARIB
# 204                 Trinidad & Tobago               LATIN AMER. & CARIB
# 198                            Taiwan         ASIA (EX. NEAR EAST)
# 97                               Iraq   NEAR EAST
# ...

# %%
df.memory_usage()
# Out:
# Index       132
# Country    1816
# Region     1816
# dtype: int64
